# %%
import pandas as pd
import re

# %% [markdown]
# # Tentativa de Automação

# %%
dias = ["SEG", "TER", "QUA", "QUI", "SEX", "SAB"]

intervalos_inicio = {"07:30": 1, "08:20" : 2, "09:20": 3, "10:10": 4, "11:00": 5, "11:50": 6,
                    "13:30": 7, "14:20" : 8, "15:20": 9, "16:10": 10, "17:00": 11, "17:50": 12,
                    "18:50": 13, "19:40": 14, "20:40": 15, "21:30": 16}

intervalos_fim = {"08:19": 1, "09:09" : 2, "09:10" : 2, "10:09": 3, "10:59": 4, "11:49": 5, "11:50": 5, "12:40": 6, "12:39": 6,
                 "14:19": 7, "15:09" : 8, "15:10" : 8, "16:09": 9, "16:59": 10, "17:49": 11, "17:50": 11 ,"18:40": 12, "18:39": 12,
                  "19:39": 13, "20:29": 14, "20:30": 14, "21:29": 15, "22:20": 16}

# %%
def separate_time_slots(inp_str):
    # Regular expression to find day and time intervals
    pattern = re.compile(r'\b(?:[A-Z]{3} \d{2}:\d{2}~\d{2}:\d{2})\b')

    # Find all occurrences of day and time intervals using the pattern
    result = re.findall(pattern, inp_str)

    return result

# %%
def timeslot_to_index(timeslot_str):
    # Regular expression to extract the time interval from the time slot
    pattern = re.compile(r'([A-Z]{3}) (\d{2}:\d{2})~(\d{2}:\d{2})')
    
    # Find the time interval using the pattern
    match = re.search(pattern, timeslot_str)

    day = match.group(1)
    first_slot = match.group(2)
    last_slot = match.group(3)
    first_index = intervalos_inicio.get(first_slot)
    last_index = intervalos_fim.get(last_slot)
    return day, first_index, last_index

# %%
def process_timeslots(inp):
    lecture_ts = separate_time_slots(inp)
    day_indexes = {}
    for ts in lecture_ts:
        day, first_index, last_index = timeslot_to_index(ts)
        if last_index == None:
            print(ts)
        indexes = list(range(first_index, last_index + 1))
        if day in day_indexes:
            day_indexes[day].extend(indexes)
        else:
            day_indexes[day] = indexes
    return day_indexes

# %%
# Apply the process_timeslots function to the "Horarios" column and create/update corresponding columns
def sheet_analisys(df):
    for index, row in df.iterrows():
        day_indexes = process_timeslots(row["HORáRIOS"])
        for day, indexes in day_indexes.items():
            df.at[index, day] = ", ".join(str(i) for i in indexes)
    return df

# %% [markdown]
# ## Teste

# %%
import os

dir_path = "../../data/og-sol/"
dir = os.listdir(dir_path)

for file_name in dir:
    if file_name.endswith(".xls") or file_name.endswith(".xlsx"):
        file_path = os.path.join(dir_path, file_name)
        print(file_path)
        df = pd.read_excel(file_path)
        df2 = sheet_analisys(df.copy())
        df2.to_excel(dir_path+"corrigido-vao-se-foderem-corpo-administrativo-do-if/"+file_name,index=False)
        display(df2)
# Out:
# ../../data/og-sol/TCC-Instancia-20181.xlsx
#      CóDIGO              TURMA CóD. DISCIPLINA  \
# 0    114936     02CDC20I.3IESP       RV.BCC011
# 1    104699  20181.02ADM112.1V        RV.ADM01
# 2    104696  20181.02ADM112.1V        RV.ADM02
# 3    104694  20181.02ADM112.1V        RV.ADM03
# 4    104700  20181.02ADM112.1V        RV.ADM04
# ..      ...                ...             ...
# 588   99546  20181.02ZOO20I.9V       RV.HUM209
# 589   99542  20181.02ZOO20I.9V       RV.ZOO216
# 590   99544  20181.02ZOO20I.9V       RV.ZOO218
# 591   99547  20181.02ZOO20I.9V       RV.ZOO219
# 592   99543  20181.02ZOO20I.9V       RV.ZOO220
#
#                               COMPONENTE CURRICULAR  \
# 0                   PROGRAMAçãO ORIENTADA A OBJETOS
# 1                        REDAçãO DE TEXTOS OFICIAIS
# 2                                             ÉTICA
# 3                    CENáRIOS ECONôMICOS E MERCADOS
# 4               SOCIOLOGIA APLICADA à ADMINISTRAçãO
# ..                                              ...
# 588                              GESTãO DE NEGóCIOS
# 589                                      AVICULTURA
# 590                   CAPRINOCULTURA E OVINOCULTURA
# 591  JULGAMENTO E PREPARO DE ANIMAIS PARA EXPOSIçãO
# 592                          BOVINOCULTURA DE LEITE
#
#                               HORáRIOS             PROFESSORES DO DIáRIO  \
# 0    [SEX 10:10~11:50 SEX 13:30~15:09]          EDGAR PEREIRA DOS SANTOS
# 1    [QUA 13:30~15:09 QUA 15:20~16:09]            WILCIENE NUNES DO VALE
# 2                    [SEG 15:20~17:50]         MILTON BERNARDES FERREIRA
# 3                    [SEX 15:20~17:50]              HAIHANI SILVA PASSOS
# 4                    [QUA 16:10~17:50]  ROBERTO EDUARDO CASTILLO PIZARRO
# ..                                 ...                               ...
# 588  [QUA 13:30~15:09 QUA 15:20~16:09]   CARLOS ANTONIO CARDOSO SOBRINHO
# 589  [SEG 13:30~15:09 SEG 15:20~16:59]          FABIANA RAMOS DOS SANTOS
# 590  [TER 13:30~15:09 TER 15:20~16:59]              ELIS APARECIDO BENTO
# 591                  [QUI 13:30~15:09]            ADRIANO CARVALHO COSTA
# 592  [SEX 13:30~15:09 SEX 15:20~16:59]            KáTIA CYLENE GUIMARãES
#
#              SEX      QUA          SEG          TER   QUI  SAB
# 0     4, 5, 7, 8      NaN          NaN          NaN   NaN  NaN
# 1            NaN  7, 8, 9          NaN          NaN   NaN  NaN
# 2            NaN      NaN    9, 10, 11          NaN   NaN  NaN
# 3      9, 10, 11      NaN          NaN          NaN   NaN  NaN
# 4            NaN   10, 11          NaN          NaN   NaN  NaN
# ..           ...      ...          ...          ...   ...  ...
# 588          NaN  7, 8, 9          NaN          NaN   NaN  NaN
# 589          NaN      NaN  7, 8, 9, 10          NaN   NaN  NaN
# 590          NaN      NaN          NaN  7, 8, 9, 10   NaN  NaN
# 591          NaN      NaN          NaN          NaN  7, 8  NaN
# 592  7, 8, 9, 10      NaN          NaN          NaN   NaN  NaN
#
# [593 rows x 12 columns]
# ../../data/og-sol/TCC-Instancia-20182.xlsx
#      CóDIGO                TURMA CóD. DISCIPLINA  \
# 0    111622    20182.02ADM112.1V        RV.ADM01
# 1    111619    20182.02ADM112.1V        RV.ADM02
# 2    111617    20182.02ADM112.1V        RV.ADM03
# 3    111623    20182.02ADM112.1V        RV.ADM04
# 4    111620    20182.02ADM112.1V       RV.ADM401
# ..      ...                  ...             ...
# 554  110914    20182.02ZOO20I.8M       RV.HUM205
# 555  110911    20182.02ZOO20I.8M       RV.HUM207
# 556  110910    20182.02ZOO20I.8M       RV.ZOO217
# 557  110912    20182.02ZOO20I.8M       RV.ZOO225
# 558  113487  20182.O2CIV20I.7ESP       RV.ENG245
#
#                         COMPONENTE CURRICULAR  \
# 0                  REDAçãO DE TEXTOS OFICIAIS
# 1                                       ÉTICA
# 2              CENáRIOS ECONôMICOS E MERCADOS
# 3         SOCIOLOGIA APLICADA à ADMINISTRAçãO
# 4                         GESTãO EMPRESARIAL
# ..                                        ...
# 554               SOCIOLOGIA E EXTENSãO RURAL
# 555                            ECONOMIA RURAL
# 556  BOVINOCULTURA DE CORTE E BUBALINOCULTURA
# 557                    NUTRIçãO DE RUMINANTES
# 558                      ESTRUTURAS METáLICAS
#
#                               HORáRIOS             PROFESSORES DO DIáRIO  \
# 0                    [TER 16:10~17:50]            WILCIENE NUNES DO VALE
# 1    [SEX 13:30~15:09 SEX 15:20~16:09]              THOMAZ JOEZER HERLER
# 2    [TER 13:30~15:09 TER 15:20~16:09]              HAIHANI SILVA PASSOS
# 3                    [QUA 15:20~16:59]  ROBERTO EDUARDO CASTILLO PIZARRO
# 4    [TER 15:20~16:59 QUA 13:30~15:09]        LUCIENE DE OLIVEIRA GUERRA
# ..                                 ...                               ...
# 554                  [QUI 09:20~11:50]                JESIEL SOUZA SILVA
# 555  [SEX 07:30~09:09 SEX 09:20~10:09]           SAMANTHA REZENDE MENDES
# 556  [TER 07:30~09:09 QUI 07:30~09:09]                KAREN MARTINS LEãO
# 557  [QUA 07:30~09:09 QUA 09:20~10:09]            KáTIA CYLENE GUIMARãES
# 558  [QUA 18:50~20:29 QUA 20:40~22:20]      ALEXSANDRO DOS SANTOS FELIPE
#
#          TER      SEX             QUA  SEG      QUI  SAB
# 0     10, 11      NaN             NaN  NaN      NaN  NaN
# 1        NaN  7, 8, 9             NaN  NaN      NaN  NaN
# 2    7, 8, 9      NaN             NaN  NaN      NaN  NaN
# 3        NaN      NaN           9, 10  NaN      NaN  NaN
# 4      9, 10      NaN            7, 8  NaN      NaN  NaN
# ..       ...      ...             ...  ...      ...  ...
# 554      NaN      NaN             NaN  NaN  3, 4, 5  NaN
# 555      NaN  1, 2, 3             NaN  NaN      NaN  NaN
# 556     1, 2      NaN             NaN  NaN     1, 2  NaN
# 557      NaN      NaN         1, 2, 3  NaN      NaN  NaN
# 558      NaN      NaN  13, 14, 15, 16  NaN      NaN  NaN
#
# [559 rows x 12 columns]
# ../../data/og-sol/TCC-Instancia-20191.xlsx
#      CóDIGO              TURMA CóD. DISCIPLINA  \
# 0    130164  20191.02ADI11N.1N        RV.ADM01
# 1    130161  20191.02ADI11N.1N        RV.ADM02
# 2    130159  20191.02ADI11N.1N        RV.ADM03
# 3    130165  20191.02ADI11N.1N        RV.ADM04
# 4    130162  20191.02ADI11N.1N       RV.ADM401
# ..      ...                ...             ...
# 616  123441   20191.02ZOO20I.9       RV.HUM209
# 617  123437   20191.02ZOO20I.9       RV.ZOO216
# 618  123439   20191.02ZOO20I.9       RV.ZOO218
# 619  123442   20191.02ZOO20I.9       RV.ZOO219
# 620  123438   20191.02ZOO20I.9       RV.ZOO220
#
#                               COMPONENTE CURRICULAR  \
# 0                        REDAçãO DE TEXTOS OFICIAIS
# 1                                             ÉTICA
# 2                    CENáRIOS ECONôMICOS E MERCADOS
# 3               SOCIOLOGIA APLICADA à ADMINISTRAçãO
# 4                               GESTãO EMPRESARIAL
# ..                                              ...
# 616                              GESTãO DE NEGóCIOS
# 617                                      AVICULTURA
# 618                   CAPRINOCULTURA E OVINOCULTURA
# 619  JULGAMENTO E PREPARO DE ANIMAIS PARA EXPOSIçãO
# 620                          BOVINOCULTURA DE LEITE
#
#                               HORáRIOS  \
# 0    [SEG 20:40~22:20 QUI 19:40~20:29]
# 1    [QUA 18:50~20:29 QUA 20:40~21:29]
# 2                    [SEX 20:40~22:20]
# 3                    [TER 20:40~22:20]
# 4    [TER 18:50~20:29 QUA 21:30~22:20]
# ..                                 ...
# 616                  [QUA 09:20~11:50]
# 617  [SEX 07:30~09:09 SEX 09:20~10:59]
# 618  [SEG 08:20~09:09 SEG 09:20~11:50]
# 619                  [QUA 07:30~09:09]
# 620  [TER 07:30~09:09 TER 09:20~10:59]
#
#                                  PROFESSORES DO DIáRIO         SEG  QUI  \
# 0                            MARISTELA SILVESTRE SILVA      15, 16   14
# 1                   VIVIANE DE FáTIMA CARDOSO OLIVEIRA         NaN  NaN
# 2                               ADEMIR XAVIER DE SOUZA         NaN  NaN
# 3                   VIVIANE DE FáTIMA CARDOSO OLIVEIRA         NaN  NaN
# 4                   VIVIANE DE FáTIMA CARDOSO OLIVEIRA         NaN  NaN
# ..                                                 ...         ...  ...
# 616                    CARLOS ANTONIO CARDOSO SOBRINHO         NaN  NaN
# 617                           FABIANA RAMOS DOS SANTOS         NaN  NaN
# 618                               ELIS APARECIDO BENTO  2, 3, 4, 5  NaN
# 619  ANA PAULA CARDOSO GOMIDE; BRUNO FRAUZINO RIBEI...         NaN  NaN
# 620                            TIAGO PEREIRA GUIMARãES         NaN  NaN
#
#             QUA         SEX         TER  SAB
# 0           NaN         NaN         NaN  NaN
# 1    13, 14, 15         NaN         NaN  NaN
# 2           NaN      15, 16         NaN  NaN
# 3           NaN         NaN      15, 16  NaN
# 4            16         NaN      13, 14  NaN
# ..          ...         ...         ...  ...
# 616     3, 4, 5         NaN         NaN  NaN
# 617         NaN  1, 2, 3, 4         NaN  NaN
# 618         NaN         NaN         NaN  NaN
# 619        1, 2         NaN         NaN  NaN
# 620         NaN         NaN  1, 2, 3, 4  NaN
#
# [621 rows x 12 columns]
# ../../data/og-sol/TCC-Instancia-20192.xlsx
#      CóDIGO                    TURMA CóD. DISCIPLINA  \
# 0    137689        20192.02ADI11N.1N        RV.ADM01
# 1    137686        20192.02ADI11N.1N        RV.ADM02
# 2    137684        20192.02ADI11N.1N        RV.ADM03
# 3    137690        20192.02ADI11N.1N        RV.ADM04
# 4    137687        20192.02ADI11N.1N       RV.ADM401
# ..      ...                      ...             ...
# 569  133506  20192.02ZOO20I.ESPECIAL       RV.BIO201
# 570  133509  20192.02ZOO20I.ESPECIAL       RV.EXA201
# 571  133511  20192.02ZOO20I.ESPECIAL       RV.QUI205
# 572  135687  20192.02ZOO20I.ESPECIAL       RV.ZOO202
# 573  133441  20192.02ZOO20I.ESPECIAL       RV.ZOO223
#
#                     COMPONENTE CURRICULAR                           HORáRIOS  \
# 0              REDAçãO DE TEXTOS OFICIAIS  [SEG 21:30~22:20 QUI 20:40~22:20]
# 1                                   ÉTICA  [TER 18:50~20:29 QUA 18:50~19:39]
# 2          CENáRIOS ECONôMICOS E MERCADOS  [QUA 19:40~20:29 SEX 21:30~22:20]
# 3     SOCIOLOGIA APLICADA à ADMINISTRAçãO  [SEX 19:40~20:29 SEX 20:40~21:29]
# 4                     GESTãO EMPRESARIAL   [SEG 18:50~20:29 SEG 20:40~21:29]
# ..                                    ...                                ...
# 569                      BIOLOGIA CELULAR  [QUA 13:30~16:09 QUI 13:30~16:09]
# 570  GEOMETRIA ANALíTICA E ÁLGEBRA LINEAR                  [QUI 07:30~10:59]
# 571             QUíMICA GERAL E ANALíTICA  [QUA 09:20~11:49 QUI 16:10~17:49]
# 572                       ANATOMIA ANIMAL                  [QUA 13:30~16:59]
# 573                     FORRAGICULTURA II                  [TER 07:30~09:10]
#
#                                  PROFESSORES DO DIáRIO         SEG  \
# 0                       FRANCIELLE FERREIRA DE FREITAS          16
# 1                       FRANCIELLE FERREIRA DE FREITAS         NaN
# 2                               ADEMIR XAVIER DE SOUZA         NaN
# 3                       FRANCIELLE FERREIRA DE FREITAS         NaN
# 4                           FREDERICO DE MORAIS BORGES  13, 14, 15
# ..                                                 ...         ...
# 569  MARIA ANDREIA CORREA MENDONçA; VALDNéA CASAGRA...         NaN
# 570         ALINE GOBBI DUTRA; TIAGO PEREIRA GUIMARãES         NaN
# 571                        ROBERTA DE ALMEIDA CARVALHO         NaN
# 572                      BRUNO FRAUZINO RIBEIRO CAMILO         NaN
# 573                     KáTIA APARECIDA DE PINHO COSTA         NaN
#
#             QUI     TER          QUA     SEX  SAB
# 0        15, 16     NaN          NaN     NaN  NaN
# 1           NaN  13, 14           13     NaN  NaN
# 2           NaN     NaN           14      16  NaN
# 3           NaN     NaN          NaN  14, 15  NaN
# 4           NaN     NaN          NaN     NaN  NaN
# ..          ...     ...          ...     ...  ...
# 569     7, 8, 9     NaN      7, 8, 9     NaN  NaN
# 570  1, 2, 3, 4     NaN          NaN     NaN  NaN
# 571      10, 11     NaN      3, 4, 5     NaN  NaN
# 572         NaN     NaN  7, 8, 9, 10     NaN  NaN
# 573         NaN    1, 2          NaN     NaN  NaN
#
# [574 rows x 12 columns]
# ../../data/og-sol/TCC-Instancia-20221.xlsx
#      CóDIGO               TURMA      CóD. DISCIPLINA  \
# 0    183444   20221.02ADM11N.1N             RV.ADM01
# 1    183441   20221.02ADM11N.1N             RV.ADM02
# 2    183439   20221.02ADM11N.1N             RV.ADM03
# 3    183445   20221.02ADM11N.1N             RV.ADM04
# 4    183442   20221.02ADM11N.1N            RV.ADM401
# ..      ...                 ...                  ...
# 447  182527  20221.02ZOO20I.7MV         GRAD.TPOA.01
# 448  182533  20221.02ZOO20I.9MV      GRAD.AVICULT.01
# 449  182534  20221.02ZOO20I.9MV           GRAD.BL.01
# 450  182543  20221.02ZOO20I.9MV  GRAD.EMPREEDAGRO.01
# 451  182544  20221.02ZOO20I.9MV           GRAD.EP.02
#
#                        COMPONENTE CURRICULAR  \
# 0                 REDAçãO DE TEXTOS OFICIAIS
# 1                                      ÉTICA
# 2             CENáRIOS ECONôMICOS E MERCADOS
# 3        SOCIOLOGIA APLICADA à ADMINISTRAçãO
# 4                        GESTãO EMPRESARIAL
# ..                                       ...
# 447  TECNOLOGIA DE PRODUTOS DE ORIGEM ANIMAL
# 448                               AVICULTURA
# 449                   BOVINOCULTURA DE LEITE
# 450          EMPREENDEDORISMO NO AGRONEGóCIO
# 451                       ÉTICA PROFISSIONAL
#
#                               HORáRIOS           PROFESSORES DO DIáRIO  \
# 0                    [SEG 20:40~22:20]        SANDRA MARA SANTOS LEMOS
# 1                    [SEX 18:50~20:29]             LORENA AZEVEDO LIMA
# 2                    [QUA 20:40~22:20]         SAMANTHA REZENDE MENDES
# 3                    [SEG 18:50~20:29]         EMIVAL DA CUNHA RIBEIRO
# 4    [TER 18:50~20:29 TER 20:40~22:20]       KENNEDY DE ARAúJO BARBOSA
# ..                                 ...                             ...
# 447  [QUA 07:30~09:09 QUA 09:20~10:09]  MARCO ANTôNIO PEREIRA DA SILVA
# 448  [SEG 13:30~15:09 SEG 15:20~16:09]        FABIANA RAMOS DOS SANTOS
# 449  [QUA 13:30~15:09 QUA 15:20~16:09]         TIAGO PEREIRA GUIMARãES
# 450                  [QUA 16:10~18:39]             LORENA AZEVEDO LIMA
# 451                  [SEG 16:10~17:49]            ELIS APARECIDO BENTO
#
#          SEG     SEX         QUA             TER  QUI  SAB
# 0     15, 16     NaN         NaN             NaN  NaN  NaN
# 1        NaN  13, 14         NaN             NaN  NaN  NaN
# 2        NaN     NaN      15, 16             NaN  NaN  NaN
# 3     13, 14     NaN         NaN             NaN  NaN  NaN
# 4        NaN     NaN         NaN  13, 14, 15, 16  NaN  NaN
# ..       ...     ...         ...             ...  ...  ...
# 447      NaN     NaN     1, 2, 3             NaN  NaN  NaN
# 448  7, 8, 9     NaN         NaN             NaN  NaN  NaN
# 449      NaN     NaN     7, 8, 9             NaN  NaN  NaN
# 450      NaN     NaN  10, 11, 12             NaN  NaN  NaN
# 451   10, 11     NaN         NaN             NaN  NaN  NaN
#
# [452 rows x 12 columns]

# %% [markdown]
# # Analise de dados

# %%
def sexto_horario(df):
    # Values to count
    values_to_count = [6,12]
    # Count occurrences of values in the specified columns for each row
    df["Total_Count"] = df[["SEG", "TER", "QUA", "QUI", "SEX", "SAB"]].isin(values_to_count).sum(axis=1)
    
    # Get the total sum of occurrences
    total_sum = df["Total_Count"].sum()
    print(total_sum)

# %%
dir_path = "../../data/og-sol/corrigido-vao-se-foderem-corpo-administrativo-do-if/"

dir = os.listdir(dir_path)

for file_name in dir:
    if file_name.endswith(".xls") or file_name.endswith(".xlsx"):
        file_path = os.path.join(dir_path, file_name)
        print(file_path)
        df = pd.read_excel(file_path)
        sexto_horario(df)
        #with open(dir_path + file_name.split(".")[0] + "analise.txt", 'w') as f:
            #print(f"Sextos Horarios: {sexto_horario(df)}\n", file=f)
            #print(f"Janelas: \n", file=f)
# Out:
# ../../data/og-sol/corrigido-vao-se-foderem-corpo-administrativo-do-if/TCC-Instancia-20181.xlsx
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 10
#       8 print(file_path)
#       9 df = pd.read_excel(file_path)
# ---> 10 sexto_horario(df)
#      11 #with open(dir_path + file_name.split(".")[0] + "analise.txt", 'w') as f:
#      12     #print(f"Sextos Horarios: {sexto_horario(df)}\n", file=f)
#      13     #print(f"Janelas: \n", file=f)
#
# Cell In[37], line 5, in sexto_horario(df)
#       3 values_to_count = [6,12]
#       4 # Count occurrences of values in the specified columns for each row
# ----> 5 df["Total_Count"] = df[["Seg", "Ter", "Qua", "Qui", "Sex", "Sab"]].isin(values_to_count).sum(axis=1)
#       7 # Get the total sum of occurrences
#       8 total_sum = df["Total_Count"].sum()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
#    5881     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5936     if use_interval_msg:
#    5937         key = list(key)
# -> 5938     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5940 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5941 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Seg', 'Ter', 'Qua', 'Qui', 'Sex', 'Sab'], dtype='object')] are in the [columns]"
